# %%
import os
import pandas as pd
from tqdm import tqdm

def read_patch_paths(image_folder, mask_folder):
    image_paths = []
    mask_paths = []

    # Get a list of image patch files in the folder
    image_files = os.listdir(image_folder)

    # Assuming the file names are the same in the mask folder
    for file_name in tqdm(image_files):
        image_path = os.path.join(image_folder, file_name)
        mask_path = os.path.join(mask_folder, file_name)

        # Check if both image and mask paths exist
        if os.path.exists(image_path) and os.path.exists(mask_path):
            image_paths.append(image_path)
            mask_paths.append(mask_path)

    # Create a DataFrame
    df = pd.DataFrame({'Image': image_paths, 'Mask': mask_paths})
    return df

# Specify the paths to the image and mask patch folders
image_patch_folder = "/kaggle/input/training-patches-he-512-idrid/HE_patches - Copy/image_patches_512/"
mask_patch_folder = "/kaggle/input/training-patches-he-512-idrid/HE_patches - Copy/mask_patches_512/"

# Read patch paths and create a DataFrame
df_patches = read_patch_paths(image_patch_folder, mask_patch_folder)
# Out:
# 100%|██████████| 1168/1168 [00:03<00:00, 373.92it/s]

# %%
df_patches.head()
# Out:
#                                                Image  \
# 0  /kaggle/input/training-patches-he-512-idrid/HE...
# 1  /kaggle/input/training-patches-he-512-idrid/HE...
# 2  /kaggle/input/training-patches-he-512-idrid/HE...
# 3  /kaggle/input/training-patches-he-512-idrid/HE...
# 4  /kaggle/input/training-patches-he-512-idrid/HE...
#
#                                                 Mask
# 0  /kaggle/input/training-patches-he-512-idrid/HE...
# 1  /kaggle/input/training-patches-he-512-idrid/HE...
# 2  /kaggle/input/training-patches-he-512-idrid/HE...
# 3  /kaggle/input/training-patches-he-512-idrid/HE...
# 4  /kaggle/input/training-patches-he-512-idrid/HE...

# %%
#for multiclass
import cv2
import numpy as np
import albumentations as A
from tensorflow.keras.utils import Sequence
from sklearn.preprocessing import MinMaxScaler

scaler=MinMaxScaler()
def apply_clahe(image):
    lab = cv2.cvtColor(image, cv2.COLOR_BGR2LAB)
    l, a, b = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    cl = clahe.apply(l)
    limg = cv2.merge((cl, a, b))
    clahe_image = cv2.cvtColor(limg, cv2.COLOR_LAB2RGB)
    return clahe_image

class CustomDataGenerator(Sequence):
    def __init__(self, df, batch_size, image_size, shuffle=True):
        self.df = df
        self.batch_size = batch_size
        self.image_size = image_size
        self.shuffle = shuffle
        self.on_epoch_end()
        self.transform = A.Compose([
            A.HorizontalFlip(p=0.5),
            A.VerticalFlip(p=0.5),
            #A.RandomBrightnessContrast(p=0.2),
            #A.Rotate(limit=10, p=0.3)
        ])

    def __len__(self):
        return int(np.ceil(len(self.df) / float(self.batch_size)))

    def on_epoch_end(self):
        if self.shuffle:
            self.df = self.df.sample(frac=1).reset_index(drop=True)

    def __getitem__(self, index):
        batch_df = self.df[index * self.batch_size : (index + 1) * self.batch_size]

        images = []
        masks = []

        for i, row in batch_df.iterrows():

            image = cv2.imread(row['Image'], cv2.IMREAD_COLOR)
            image = apply_clahe(image)
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            image = cv2.resize(image, self.image_size)
            #shape = image.shape
            #image = scaler.fit_transform(image.reshape(-1, shape[-1])).reshape(shape)
            image = image/np.max(image)
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

            mask_path = row['Mask']
            if mask_path:
                mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
                mask = cv2.resize(mask, self.image_size)
                mask=mask>0
    

            augmented = self.transform(image=image, mask=mask)
            images.append(augmented['image'])
            masks.append(augmented['mask'])
        
                

        #images = np.expand_dims(np.array(images, dtype=np.float32), axis=-1)
        images = np.array(images, dtype=np.float32)
        masks = np.expand_dims(np.array(masks, dtype=np.float32), axis=-1)
        return  images, masks

# Example usage of the CustomDataGenerator
train_generator = CustomDataGenerator(df_patches, batch_size=8, image_size=(256, 256), shuffle=True)
# Out:
# 2024-02-01 12:17:55.001874: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-01 12:17:55.001996: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-01 12:17:55.136194: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
import matplotlib.pyplot as plt

# Load a single batch
batch = train_generator[0]  # Assuming you want to load the first batch

# Extract images and labels from the batch
images, masks = batch

# Display the images and masks
n_images_to_display = len(images)
fig, ax = plt.subplots(n_images_to_display, 2, figsize=(10, 20))
for i in range(n_images_to_display):
    ax[i, 0].imshow(images[i], cmap='bone')
    #print(np.max(images[i]))
    ax[i, 0].set_title('Image')
    ax[i, 1].imshow(masks[i], cmap='bone')
    #print(np.max(masks[i]))
    ax[i, 1].set_title('Mask')

    ax[i, 0].axis('off')
    ax[i, 1].axis('off')
plt.show()

# %%
from sklearn.model_selection import train_test_split

df_shuffled = df_patches.sample(frac=1, random_state=42)
train_df, val_df = train_test_split(df_shuffled, test_size=0.2, random_state=42)

# %%
# bar plot
from matplotlib import pyplot as plt
sizes = [len(train_df), len(val_df)]
labels = ['Train', 'Validation']

plt.bar(labels, sizes, color=['blue', 'orange'])
plt.xlabel('Data Split')
plt.ylabel('Number of Samples')
plt.title('Dataset Split: Train, Validation')
plt.show()

# %% [markdown]
# # Model Architecture and Helper blocks

# %%
#GCSE Block...from the GCSER UNET (Mukherjee et al.)
def GCSE(input_tensor, ratio=16):


    # Compute the global statistics (mean and std deviation) along the channel axis.
    mean = tf.reduce_mean(input_tensor, axis=[1, 2], keepdims=True)
    std = tf.math.reduce_std(input_tensor, axis=[1, 2], keepdims=True)

    # Compute channel-wise attention using a convolutional neural network.
    attn_channel = tf.concat([mean, std], axis=-1)
    attn_channel = tf.keras.layers.Conv2D(filters=input_tensor.shape[-1] // ratio, kernel_size=(1, 1), activation='relu')(attn_channel)
    attn_channel = tf.keras.layers.Conv2D(filters=input_tensor.shape[-1], kernel_size=(1, 1), activation='sigmoid')(attn_channel)

    # Compute spatial attention using global information from the input tensor.
    global_info = tf.reduce_mean(input_tensor, axis=-1, keepdims=True)
    attn_spatial = tf.keras.layers.Conv2D(filters=1, kernel_size=(1, 1), activation='sigmoid')(global_info)

    # Combine channel-wise and spatial attention.
    attn = tf.keras.layers.Multiply()([attn_channel,attn_spatial])

    # Multiply the input tensor by the learned attention weights.
    output_tensor = tf.keras.layers.Multiply()([input_tensor,attn])

    return output_tensor

# %%
def ASPP(x, filter):
    shape = x.shape

    y1 = AveragePooling2D(pool_size=(shape[1], shape[2]))(x)
    y1 = Conv2D(filter, 1, padding="same")(y1)
    y1 = BatchNormalization()(y1)
    y1 = Activation("relu")(y1)
    y1 = UpSampling2D((shape[1], shape[2]), interpolation="bilinear")(y1)

    y2 = Conv2D(filter, 1, dilation_rate=1, padding="same", use_bias=False)(x)
    y2 = BatchNormalization()(y2)
    y2 = Activation("relu")(y2)

    y3 = Conv2D(filter, 3, dilation_rate=3, padding="same", use_bias=False)(x)
    y3 = BatchNormalization()(y3)
    y3 = Activation("relu")(y3)

    y4 = Conv2D(filter, 3, dilation_rate=5, padding="same", use_bias=False)(x)
    y4 = BatchNormalization()(y4)
    y4 = Activation("relu")(y4)

    y5 = Conv2D(filter, 3, dilation_rate=7, padding="same", use_bias=False)(x)
    y5 = BatchNormalization()(y5)
    y5 = Activation("relu")(y5)

    y = Concatenate()([y1, y2, y3, y4, y5])

    y = Conv2D(filter, 1, dilation_rate=1, padding="same", use_bias=False)(y)
    y = BatchNormalization()(y)
    y = Activation("relu")(y)

    return y

# %% [markdown]
# # GCSER UNet Architecture

# %%
# Code for W-Net
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.layers import Conv2D,Conv2DTranspose, BatchNormalization, Activation, MaxPool2D, UpSampling2D, Concatenate, Input, ZeroPadding2D,Dropout,Dense,MaxPooling2D,Reshape,Multiply,GlobalAveragePooling2D,AveragePooling2D
from tensorflow.keras.models import Model


def batchnorm_relu(inputs):
    x = BatchNormalization()(inputs)
    #x = Activation("relu")(x)
    x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)
    return x

def residual_block(inputs, num_filters):
    """ Convolutional Layer """
    x = batchnorm_relu(inputs)
    x = Conv2D(num_filters, 3, padding="same", strides=1,kernel_initializer = "he_normal")(x)
    x = Dropout(0.1)(x)
    x = batchnorm_relu(x)
    x = Conv2D(num_filters, 3, padding="same", strides=1,kernel_initializer = "he_normal")(x)


    """ Shortcut Connection """
    s = Conv2D(num_filters, 1, padding="same", strides=1,kernel_initializer="he_normal")(inputs)
    x = x + s
    return x

def decoder_block(inputs, s1, num_filters):
    x = Conv2DTranspose(num_filters,2, strides=(2,2), kernel_initializer="he_normal",padding = "same")(inputs)
    x = Concatenate()([x,s1])
    x = residual_block(x, num_filters)
    x = GCSE(x)
    return x
def build_encoder(inputs,f,name):
    
    x = Conv2D(f[0], 3, padding="same", strides=1,kernel_initializer="he_normal")(inputs)
    x = batchnorm_relu(x)
    x = Conv2D(f[0], 3, padding="same", strides=1,kernel_initializer="he_normal")(x)
    s = Conv2D(f[0], 1, padding="same", strides=1,kernel_initializer="he_normal")(inputs)

    c1 = x + s
    c1 = GCSE(c1)
    p1 = MaxPooling2D((2,2))(c1)
    s1 = c1

    c2 = residual_block(p1, f[1])
    c2 = GCSE(c2)
    p2 = MaxPooling2D((2,2))(c2)
    s2 = c2

    c3 = residual_block(p2, f[2])
    c3 = GCSE(c3)
    p3 = MaxPooling2D((2,2))(c3)
    s3 = c3

    c4 = residual_block(p3, f[3])
    c4 = GCSE(c4)
    p4 = MaxPooling2D((2,2))(c4)
    s4 = c4
    
    s_ = [s1,s2,s3,s4]
    """ Bridge """
    b = ASPP(p4,128)
    encoder1 = Model(inputs,outputs=[s_,b],name=name)
    return encoder1

    
    

def build_UNet(input_shape):
    f = [32,64,128,256]

    inputs = Input(input_shape,name="model_input")
    encoder = build_encoder(inputs,f,name="encoder1")

    s,b = encoder(inputs)

    """ Decoder 1, 2, 3... """
    d1 = decoder_block(b, s[3], f[3])
    d2 = decoder_block(d1, s[2], f[2])
    d3 = decoder_block(d2, s[1], f[1])
    d4 = decoder_block(d3, s[0], f[0])
    

    """ Segmentation output """
    output_1 = Conv2D(1, (1,1) , activation="sigmoid",name='output_1')(d4)

    """ Model """
    model = Model(inputs,outputs=output_1)
    return model

# %% [markdown]
# # Evaluation Metrics

# %%
from keras import backend as K
import tensorflow as tf
epsilon = 1e-5
smooth = 1e-5

def dice_coeff(y_true, y_pred, smooth=1e-5):
    y_true_flatten = K.flatten(y_true)
    y_pred_flatten = K.flatten(y_pred)
    intersection = K.sum(y_true_flatten * y_pred_flatten)
    dice = (2. * intersection + smooth) / (K.sum(y_true_flatten) + K.sum(y_pred_flatten) + smooth)
    return dice

def dice_loss(y_true, y_pred):
    return  1- dice_coeff(y_true, y_pred, smooth=1e-5)

def FocalLoss(targets, inputs, alpha=0.25, gamma=2):    
    
    inputs = K.flatten(inputs)
    targets = K.flatten(targets)
    
    BCE = K.binary_crossentropy(targets, inputs)
    BCE_EXP = K.exp(-BCE)
    focal_loss = K.mean(alpha * K.pow((1-BCE_EXP), gamma) * BCE)
    
    return focal_loss

def total_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    return dice_loss(y_true, y_pred) + FocalLoss(y_true, y_pred, 0.25,2)
def precision(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision
def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())
def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

def iou_score(y_true, y_pred):
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true + y_pred, axis=[1, 2, 3]) - intersection
    iou = (intersection + 1e-5) / (union + 1e-5)
    return iou

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint, LearningRateScheduler
from keras.callbacks import CSVLogger
model = build_UNet((256,256,3))

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  model_input (InputLayer)    [(None, 256, 256, 3)]        0         []
#
#  encoder1 (Functional)       [[(None, 256, 256, 32),      2270886   ['model_input[0][0]']
#                               (None, 128, 128, 64),
#                               (None, 64, 64, 128),
#                               (None, 32, 32, 256)],
#                               (None, 16, 16, 128)]
#
#  conv2d_transpose (Conv2DTr  (None, 32, 32, 256)          131328    ['encoder1[0][4]']
#  anspose)
#
#  concatenate_1 (Concatenate  (None, 32, 32, 512)          0         ['conv2d_transpose[0][0]',
#  )                                                                   'encoder1[0][3]']
#
#  batch_normalization_13 (Ba  (None, 32, 32, 512)          2048      ['concatenate_1[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 32, 32, 512)          0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  conv2d_30 (Conv2D)          (None, 32, 32, 256)          1179904   ['leaky_re_lu_7[0][0]']
#
#  dropout_3 (Dropout)         (None, 32, 32, 256)          0         ['conv2d_30[0][0]']
#
#  batch_normalization_14 (Ba  (None, 32, 32, 256)          1024      ['dropout_3[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_8 (LeakyReLU)   (None, 32, 32, 256)          0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  conv2d_31 (Conv2D)          (None, 32, 32, 256)          590080    ['leaky_re_lu_8[0][0]']
#
#  conv2d_32 (Conv2D)          (None, 32, 32, 256)          131328    ['concatenate_1[0][0]']
#
#  tf.__operators__.add_4 (TF  (None, 32, 32, 256)          0         ['conv2d_31[0][0]',
#  OpLambda)                                                           'conv2d_32[0][0]']
#
#  tf.math.reduce_mean_8 (TFO  (None, 1, 1, 256)            0         ['tf.__operators__.add_4[0][0]
#  pLambda)                                                           ']
#
#  tf.math.reduce_std_4 (TFOp  (None, 1, 1, 256)            0         ['tf.__operators__.add_4[0][0]
#  Lambda)                                                            ']
#
#  tf.concat_4 (TFOpLambda)    (None, 1, 1, 512)            0         ['tf.math.reduce_mean_8[0][0]'
#                                                                     , 'tf.math.reduce_std_4[0][0]'
#                                                                     ]
#
#  conv2d_33 (Conv2D)          (None, 1, 1, 16)             8208      ['tf.concat_4[0][0]']
#
#  tf.math.reduce_mean_9 (TFO  (None, 32, 32, 1)            0         ['tf.__operators__.add_4[0][0]
#  pLambda)                                                           ']
#
#  conv2d_34 (Conv2D)          (None, 1, 1, 256)            4352      ['conv2d_33[0][0]']
#
#  conv2d_35 (Conv2D)          (None, 32, 32, 1)            2         ['tf.math.reduce_mean_9[0][0]'
#                                                                     ]
#
#  multiply_8 (Multiply)       (None, 32, 32, 256)          0         ['conv2d_34[0][0]',
#                                                                      'conv2d_35[0][0]']
#
#  multiply_9 (Multiply)       (None, 32, 32, 256)          0         ['tf.__operators__.add_4[0][0]
#                                                                     ',
#                                                                      'multiply_8[0][0]']
#
#  conv2d_transpose_1 (Conv2D  (None, 64, 64, 128)          131200    ['multiply_9[0][0]']
#  Transpose)
#
#  concatenate_2 (Concatenate  (None, 64, 64, 256)          0         ['conv2d_transpose_1[0][0]',
#  )                                                                   'encoder1[0][2]']
#
#  batch_normalization_15 (Ba  (None, 64, 64, 256)          1024      ['concatenate_2[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_9 (LeakyReLU)   (None, 64, 64, 256)          0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  conv2d_36 (Conv2D)          (None, 64, 64, 128)          295040    ['leaky_re_lu_9[0][0]']
#
#  dropout_4 (Dropout)         (None, 64, 64, 128)          0         ['conv2d_36[0][0]']
#
#  batch_normalization_16 (Ba  (None, 64, 64, 128)          512       ['dropout_4[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_10 (LeakyReLU)  (None, 64, 64, 128)          0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  conv2d_37 (Conv2D)          (None, 64, 64, 128)          147584    ['leaky_re_lu_10[0][0]']
#
#  conv2d_38 (Conv2D)          (None, 64, 64, 128)          32896     ['concatenate_2[0][0]']
#
#  tf.__operators__.add_5 (TF  (None, 64, 64, 128)          0         ['conv2d_37[0][0]',
#  OpLambda)                                                           'conv2d_38[0][0]']
#
#  tf.math.reduce_mean_10 (TF  (None, 1, 1, 128)            0         ['tf.__operators__.add_5[0][0]
#  OpLambda)                                                          ']
#
#  tf.math.reduce_std_5 (TFOp  (None, 1, 1, 128)            0         ['tf.__operators__.add_5[0][0]
#  Lambda)                                                            ']
#
#  tf.concat_5 (TFOpLambda)    (None, 1, 1, 256)            0         ['tf.math.reduce_mean_10[0][0]
#                                                                     ',
#                                                                      'tf.math.reduce_std_5[0][0]']
#
#  conv2d_39 (Conv2D)          (None, 1, 1, 8)              2056      ['tf.concat_5[0][0]']
#
#  tf.math.reduce_mean_11 (TF  (None, 64, 64, 1)            0         ['tf.__operators__.add_5[0][0]
#  OpLambda)                                                          ']
#
#  conv2d_40 (Conv2D)          (None, 1, 1, 128)            1152      ['conv2d_39[0][0]']
#
#  conv2d_41 (Conv2D)          (None, 64, 64, 1)            2         ['tf.math.reduce_mean_11[0][0]
#                                                                     ']
#
#  multiply_10 (Multiply)      (None, 64, 64, 128)          0         ['conv2d_40[0][0]',
#                                                                      'conv2d_41[0][0]']
#
#  multiply_11 (Multiply)      (None, 64, 64, 128)          0         ['tf.__operators__.add_5[0][0]
#                                                                     ',
#                                                                      'multiply_10[0][0]']
#
#  conv2d_transpose_2 (Conv2D  (None, 128, 128, 64)         32832     ['multiply_11[0][0]']
#  Transpose)
#
#  concatenate_3 (Concatenate  (None, 128, 128, 128)        0         ['conv2d_transpose_2[0][0]',
#  )                                                                   'encoder1[0][1]']
#
#  batch_normalization_17 (Ba  (None, 128, 128, 128)        512       ['concatenate_3[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_11 (LeakyReLU)  (None, 128, 128, 128)        0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  conv2d_42 (Conv2D)          (None, 128, 128, 64)         73792     ['leaky_re_lu_11[0][0]']
#
#  dropout_5 (Dropout)         (None, 128, 128, 64)         0         ['conv2d_42[0][0]']
#
#  batch_normalization_18 (Ba  (None, 128, 128, 64)         256       ['dropout_5[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_12 (LeakyReLU)  (None, 128, 128, 64)         0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  conv2d_43 (Conv2D)          (None, 128, 128, 64)         36928     ['leaky_re_lu_12[0][0]']
#
#  conv2d_44 (Conv2D)          (None, 128, 128, 64)         8256      ['concatenate_3[0][0]']
#
#  tf.__operators__.add_6 (TF  (None, 128, 128, 64)         0         ['conv2d_43[0][0]',
#  OpLambda)                                                           'conv2d_44[0][0]']
#
#  tf.math.reduce_mean_12 (TF  (None, 1, 1, 64)             0         ['tf.__operators__.add_6[0][0]
#  OpLambda)                                                          ']
#
#  tf.math.reduce_std_6 (TFOp  (None, 1, 1, 64)             0         ['tf.__operators__.add_6[0][0]
#  Lambda)                                                            ']
#
#  tf.concat_6 (TFOpLambda)    (None, 1, 1, 128)            0         ['tf.math.reduce_mean_12[0][0]
#                                                                     ',
#                                                                      'tf.math.reduce_std_6[0][0]']
#
#  conv2d_45 (Conv2D)          (None, 1, 1, 4)              516       ['tf.concat_6[0][0]']
#
#  tf.math.reduce_mean_13 (TF  (None, 128, 128, 1)          0         ['tf.__operators__.add_6[0][0]
#  OpLambda)                                                          ']
#
#  conv2d_46 (Conv2D)          (None, 1, 1, 64)             320       ['conv2d_45[0][0]']
#
#  conv2d_47 (Conv2D)          (None, 128, 128, 1)          2         ['tf.math.reduce_mean_13[0][0]
#                                                                     ']
#
#  multiply_12 (Multiply)      (None, 128, 128, 64)         0         ['conv2d_46[0][0]',
#                                                                      'conv2d_47[0][0]']
#
#  multiply_13 (Multiply)      (None, 128, 128, 64)         0         ['tf.__operators__.add_6[0][0]
#                                                                     ',
#                                                                      'multiply_12[0][0]']
#
#  conv2d_transpose_3 (Conv2D  (None, 256, 256, 32)         8224      ['multiply_13[0][0]']
#  Transpose)
#
#  concatenate_4 (Concatenate  (None, 256, 256, 64)         0         ['conv2d_transpose_3[0][0]',
#  )                                                                   'encoder1[0][0]']
#
#  batch_normalization_19 (Ba  (None, 256, 256, 64)         256       ['concatenate_4[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_13 (LeakyReLU)  (None, 256, 256, 64)         0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  conv2d_48 (Conv2D)          (None, 256, 256, 32)         18464     ['leaky_re_lu_13[0][0]']
#
#  dropout_6 (Dropout)         (None, 256, 256, 32)         0         ['conv2d_48[0][0]']
#
#  batch_normalization_20 (Ba  (None, 256, 256, 32)         128       ['dropout_6[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_14 (LeakyReLU)  (None, 256, 256, 32)         0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  conv2d_49 (Conv2D)          (None, 256, 256, 32)         9248      ['leaky_re_lu_14[0][0]']
#
#  conv2d_50 (Conv2D)          (None, 256, 256, 32)         2080      ['concatenate_4[0][0]']
#
#  tf.__operators__.add_7 (TF  (None, 256, 256, 32)         0         ['conv2d_49[0][0]',
#  OpLambda)                                                           'conv2d_50[0][0]']
#
#  tf.math.reduce_mean_14 (TF  (None, 1, 1, 32)             0         ['tf.__operators__.add_7[0][0]
#  OpLambda)                                                          ']
#
#  tf.math.reduce_std_7 (TFOp  (None, 1, 1, 32)             0         ['tf.__operators__.add_7[0][0]
#  Lambda)                                                            ']
#
#  tf.concat_7 (TFOpLambda)    (None, 1, 1, 64)             0         ['tf.math.reduce_mean_14[0][0]
#                                                                     ',
#                                                                      'tf.math.reduce_std_7[0][0]']
#
#  conv2d_51 (Conv2D)          (None, 1, 1, 2)              130       ['tf.concat_7[0][0]']
#
#  tf.math.reduce_mean_15 (TF  (None, 256, 256, 1)          0         ['tf.__operators__.add_7[0][0]
#  OpLambda)                                                          ']
#
#  conv2d_52 (Conv2D)          (None, 1, 1, 32)             96        ['conv2d_51[0][0]']
#
#  conv2d_53 (Conv2D)          (None, 256, 256, 1)          2         ['tf.math.reduce_mean_15[0][0]
#                                                                     ']
#
#  multiply_14 (Multiply)      (None, 256, 256, 32)         0         ['conv2d_52[0][0]',
#                                                                      'conv2d_53[0][0]']
#
#  multiply_15 (Multiply)      (None, 256, 256, 32)         0         ['tf.__operators__.add_7[0][0]
#                                                                     ',
#                                                                      'multiply_14[0][0]']
#
#  output_1 (Conv2D)           (None, 256, 256, 1)          33        ['multiply_15[0][0]']
#
# ==================================================================================================
# Total params: 5122701 (19.54 MB)
# Trainable params: 5116877 (19.52 MB)
# Non-trainable params: 5824 (22.75 KB)
# __________________________________________________________________________________________________

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = 0.001), loss={'output_1':total_loss},
              loss_weights = {'output_1':1},
              metrics = {"output_1":[iou_score,dice_coeff,tf.keras.metrics.Precision(),
    tf.keras.metrics.Recall(),sensitivity,specificity,tf.keras.metrics.AUC()]})

#callbacks
csv_logger = CSVLogger('/kaggle/working/training_log_WCE_segmentation', separator=',', append=True)
earlystopping = EarlyStopping(monitor='val_loss',
                              mode='min', 
                              verbose=1, 
                              patience=9
                             )
# save the best model with lower validation loss
checkpointer = ModelCheckpoint(filepath="/kaggle/working/WNet_maxpool.h5", 
                               monitor="val_loss",
                               verbose=1, 
                               save_best_only=True,
                               save_weights_only=True
                              )

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=4, min_lr=1e-6, verbose=1)
                              
"""reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              mode='min',
                              verbose=1,
                              patience=4,
                              min_delta=0.000001,
                              factor=0.3
                             )"""
callbacks = [checkpointer, earlystopping, reduce_lr, csv_logger]

# %%
batch_size = 4
N = 256
train_generator = CustomDataGenerator(train_df, batch_size=batch_size, image_size=(N,N), shuffle=True)
val_generator = CustomDataGenerator(val_df, batch_size=batch_size, image_size=(N,N), shuffle=False)
num_epochs = 50

# %%
history = model.fit(train_generator, steps_per_epoch=len(train_df) // batch_size,
                    validation_data=val_generator, validation_steps=len(val_df) // batch_size,
                    epochs = num_epochs,callbacks=callbacks)
# Out:
# Epoch 1/50
# 2024-02-01 12:18:24.686720: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel/encoder1/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1706789911.285292      73 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 233/233 [==============================] - ETA: 0s - loss: 0.5464 - iou_score: 0.2603 - dice_coeff: 0.4865 - precision: 0.5056 - recall: 0.4927 - sensitivity: 0.5547 - specificity: 0.9858 - auc: 0.8236
# Epoch 1: val_loss improved from inf to 1.05197, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 74s 174ms/step - loss: 0.5464 - iou_score: 0.2603 - dice_coeff: 0.4865 - precision: 0.5056 - recall: 0.4927 - sensitivity: 0.5547 - specificity: 0.9858 - auc: 0.8236 - val_loss: 1.0520 - val_iou_score: 0.0036 - val_dice_coeff: 0.0100 - val_precision: 0.9995 - val_recall: 0.0053 - val_sensitivity: 0.0040 - val_specificity: 1.0000 - val_auc: 0.5191 - lr: 0.0010
# Epoch 2/50
# 233/233 [==============================] - ETA: 0s - loss: 0.
50
# 233/233 [==============================] - ETA: 0s - loss: 0.3164 - iou_score: 0.4560 - dice_coeff: 0.7011 - precision: 0.7928 - recall: 0.7286 - sensitivity: 0.7166 - specificity: 0.9943 - auc: 0.9184
# Epoch 16: val_loss did not improve from 0.33492
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 233/233 [==============================] - 31s 133ms/step - loss: 0.3164 - iou_score: 0.4560 - dice_coeff: 0.7011 - precision: 0.7928 - recall: 0.7286 - sensitivity: 0.7166 - specificity: 0.9943 - auc: 0.9184 - val_loss: 0.3566 - val_iou_score: 0.3958 - val_dice_coeff: 0.6669 - val_precision: 0.6992 - val_recall: 0.7533 - val_sensitivity: 0.7173 - val_specificity: 0.9908 - val_auc: 0.9016 - lr: 0.0010
# Epoch 17/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3002 - iou_score: 0.4605 - dice_coeff: 0.7173 - precision: 0.7978 - recall: 0.7263 - sensitivity: 0.7260 - specificity: 0.9945 - auc: 0.9177
# Epoch 17: val_loss did not improve from 0.33492
# 233/233 [==============================] - 31s 133ms/step - loss: 0.3002 - iou_score: 0.4605 - dice_coeff: 0.7173 - precision: 0.7978 - recall: 0.7263 - sensitivity: 0.7260 - specificity: 0.9945 - auc: 0.9177 - val_loss: 0.3915 - val_iou_score: 0.3997 - val_dice_coeff: 0.6313 - val_precision: 0.6758 - val_recall: 0.7100 - val_sensitivity: 0.6720 - val_specificity: 0.9904 - val_auc: 0.8817 - lr: 5.0000e-04
# Epoch 18/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3028 - iou_score: 0.4786 - dice_coeff: 0.7144 - precision: 0.8021 - recall: 0.7154 - sensitivity: 0.7297 - specificity: 0.9948 - auc: 0.9112
# Epoch 18: val_loss improved from 0.33492 to 0.31441, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 31s 134ms/step - loss: 0.3028 - iou_score: 0.4786 - dice_coeff: 0.7144 - precision: 0.8021 - recall: 0.7154 - sensitivity: 0.7297 - specificity: 0.9948 - auc: 0.9112 - val_loss: 0.3144 - val_iou_score: 0.4501 - val_dice_coeff: 0.6995 - val_precision: 0.7787 - val_recall: 0.7973 - val_sensitivity: 0.7084 - val_specificity: 0.9936 - val_auc: 0.9384 - lr: 5.0000e-04
# Epoch 19/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2947 - iou_score: 0.4757 - dice_coeff: 0.7216 - precision: 0.8001 - recall: 0.7216 - sensitivity: 0.7312 - specificity: 0.9946 - auc: 0.9228
# Epoch 19: val_loss improved from 0.31441 to 0.30449, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 31s 134ms/step - loss: 0.2947 - iou_score: 0.4757 - dice_coeff: 0.7216 - precision: 0.8001 - recall: 0.7216 - sensitivity: 0.7312 - specificity: 0.9946 - auc: 0.9228 - val_loss: 0.3045 - val_iou_score: 0.4635 - val_dice_coeff: 0.7096 - val_precision: 0.7575 - val_recall: 0.8175 - val_sensitivity: 0.7425 - val_specificity: 0.9926 - val_auc: 0.9479 - lr: 5.0000e-04
# Epoch 20/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3027 - iou_score: 0.4889 - dice_coeff: 0.7137 - precision: 0.7995 - recall: 0.7514 - sensitivity: 0.7283 - specificity: 0.9944 - auc: 0.9239
# Epoch 20: val_loss did not improve from 0.30449
50
# 233/233 [==============================] - ETA: 0s - loss: 0.2581 - iou_score: 0.5183 - dice_coeff: 0.7546 - precision: 0.8209 - recall: 0.7951 - sensitivity: 0.7600 - specificity: 0.9948 - auc: 0.9444
# Epoch 35: val_loss did not improve from 0.26911
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 233/233 [==============================] - 31s 133ms/step - loss: 0.2581 - iou_score: 0.5183 - dice_coeff: 0.7546 - precision: 0.8209 - recall: 0.7951 - sensitivity: 0.7600 - specificity: 0.9948 - auc: 0.9444 - val_loss: 0.2833 - val_iou_score: 0.4836 - val_dice_coeff: 0.7297 - val_precision: 0.7396 - val_recall: 0.8671 - val_sensitivity: 0.8183 - val_specificity: 0.9914 - val_auc: 0.9629 - lr: 2.5000e-04
# Epoch 36/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2580 - iou_score: 0.5219 - dice_coeff: 0.7542 - precision: 0.8218 - recall: 0.7993 - sensitivity: 0.7613 - specificity: 0.9948 - auc: 0.9477
# Epoch 36: val_loss did not improve from 0.26911
# 233/233 [==============================] - 31s 133ms/step - loss: 0.2580 - iou_score: 0.5219 - dice_coeff: 0.7542 - precision: 0.8218 - recall: 0.7993 - sensitivity: 0.7613 - specificity: 0.9948 - auc: 0.9477 - val_loss: 0.2848 - val_iou_score: 0.4789 - val_dice_coeff: 0.7286 - val_precision: 0.7313 - val_recall: 0.8762 - val_sensitivity: 0.8370 - val_specificity: 0.9909 - val_auc: 0.9651 - lr: 1.2500e-04
# Epoch 37/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2538 - iou_score: 0.5243 - dice_coeff: 0.7581 - precision: 0.8243 - recall: 0.8021 - sensitivity: 0.7639 - specificity: 0.9949 - auc: 0.9484
# Epoch 37: val_loss did not improve from 0.26911
# 233/233 [==============================] - 31s 133ms/step - loss: 0.2538 - iou_score: 0.5243 - dice_coeff: 0.7581 - precision: 0.8243 - recall: 0.8021 - sensitivity: 0.7639 - specificity: 0.9949 - auc: 0.9484 - val_loss: 0.2721 - val_iou_score: 0.4992 - val_dice_coeff: 0.7403 - val_precision: 0.7724 - val_recall: 0.8517 - val_sensitivity: 0.8035 - val_specificity: 0.9929 - val_auc: 0.9574 - lr: 1.2500e-04
# Epoch 38/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2572 - iou_score: 0.5282 - dice_coeff: 0.7549 - precision: 0.8230 - recall: 0.8030 - sensitivity: 0.7605 - specificity: 0.9948 - auc: 0.9491
# Epoch 38: val_loss did not improve from 0.26911
# 233/233 [==============================] - 31s 133ms/step - loss: 0.2572 - iou_score: 0.5282 - dice_coeff: 0.7549 - precision: 0.8230 - recall: 0.8030 - sensitivity: 0.7605 - specificity: 0.9948 - auc: 0.9491 - val_loss: 0.2760 - val_iou_score: 0.4922 - val_dice_coeff: 0.7374 - val_precision: 0.7431 - val_recall: 0.8740 - val_sensitivity: 0.8228 - val_specificity: 0.9915 - val_auc: 0.9641 - lr: 1.2500e-04
# Epoch 39/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2561 - iou_score: 0.5243 - dice_coeff: 0.7565 - precision: 0.8217 - recall: 0.7970 - sensitivity: 0.7607 - specificity: 0.9948 - auc: 0.9470
# Epoch 39: val_loss did not improve from 0.26911
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 233/233 [==============================] - 31s 133ms/step - loss: 0.2561 - iou_score: 0.5243 - dice_coeff: 0.7565 - precision: 0.8217 - recall: 0.7970 - sensitivity: 0.7607 - specificity: 0.9948 - auc: 0.9470 - val_loss: 0.2828 - val_iou_score: 0.4872 - val_dice_coeff: 0.7302 - val_precision: 0.7409 - val_recall: 0.8663 - val_sensitivity: 0.8120 - val_specificity: 0.9914 - val_auc: 0.9626 - lr: 1.2500e-04
# Epoch 40/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2576 - iou_score: 0.5310 - dice_coeff: 0.7546 - precision: 0.8246 - recall: 0.8035 - sensitivity: 0.7630 - specificity: 0.9948 - auc: 0.9492
# Epoch 40: val_loss did not improve from 0.26911
# 233/233 [==============================] - 31s 133ms/step - loss: 0.2576 - iou_score: 0.5310 - dice_coeff: 0.7546 - precision: 0.8246 - recall: 0.8035 - sensitivity: 0.7630 - specificity: 0.9948 - auc: 0.9492 - val_loss: 0.2746 - val_iou_score: 0.4924 - val_dice_coeff: 0.7381 - val_precision: 0.7528 - val_recall: 0.8638 - val_sensitivity: 0.8123 - val_specificity: 0.9920 - val_auc: 0.9619 - lr: 6.2500e-05
# Epoch 40: early stopping

# %%
model.save_weights("./final_model.h5")

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'iou_score', 'dice_coeff', 'precision', 'recall', 'sensitivity', 'specificity', 'auc', 'val_loss', 'val_iou_score', 'val_dice_coeff', 'val_precision', 'val_recall', 'val_sensitivity', 'val_specificity', 'val_auc', 'lr'])

# %%
from matplotlib import pyplot as plt
history = pd.read_csv('/kaggle/working/training_log_WCE_segmentation', sep=',', engine='python')

#history= history

############### ########## ####### #######

iou_score=history['iou_score']
val_iou_score=history['val_iou_score']

loss=history['loss']
val_loss=history['val_loss']

train_dice=history['dice_coeff']
val_dice=history['val_dice_coeff']



epoch = np.arange(len(loss))

# Create subplots
fig, axes = plt.subplots(1, 3, figsize=(18, 6))
plt.subplots_adjust(wspace=0.3)  # Adjust the space between subplots

# Plot 1: Loss
axes[0].plot(epoch, loss, 'b', label='Training Loss', linewidth=1.5)
axes[0].plot(epoch, val_loss, 'r', label='Validation Loss', linewidth=1.5)
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Loss')
axes[0].set_title('Training and Validation Loss')
axes[0].legend()

# Plot 2: IOU Scores
axes[1].plot(epoch, iou_score, 'b', label='Training IOU', linewidth=1.5)
axes[1].plot(epoch, val_iou_score, 'r', label='Validation IOU', linewidth=1.5)
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('IOU Score')
axes[1].set_title('Training and Validation IOU Score')
axes[1].legend()

# Plot 3: Dice Coefficients
axes[2].plot(epoch, train_dice, 'b', label='Training Dice Coeff', linewidth=1.5)
axes[2].plot(epoch, val_dice, 'r', label='Validation Dice Coeff', linewidth=1.5)
axes[2].set_xlabel('Epochs')
axes[2].set_ylabel('Dice Coefficient')
axes[2].set_title('Training and Validation Dice Coefficient')
axes[2].legend()

# Customize tick marks and labels
for ax in axes:
    ax.grid(True)
    ax.set_xticks(np.arange(0, len(epoch), 5))  # Adjust the x-axis ticks
    ax.set_yticks(np.arange(0, 1.1, 0.1))  # Adjust the y-axis ticks
    ax.grid(which='both', linestyle='--', linewidth=0.5)

# Display the plots
plt.tight_layout()
plt.show()

# %%
from keras import backend as K
import tensorflow as tf
epsilon = 1e-5
smooth = 1e-5

def dice_coeff(y_true, y_pred, smooth=1e-5):
    y_true_flatten = K.flatten(y_true)
    y_pred_flatten = K.flatten(y_pred)
    intersection = K.sum(y_true_flatten * y_pred_flatten)
    dice = (2. * intersection + smooth) / (K.sum(y_true_flatten) + K.sum(y_pred_flatten) + smooth)
    return dice

def dice_loss(y_true, y_pred):
    return  1- dice_coeff(y_true, y_pred, smooth=1e-5)

def FocalLoss(targets, inputs, alpha=0.25, gamma=2):    
    
    inputs = K.flatten(inputs)
    targets = K.flatten(targets)
    
    BCE = K.binary_crossentropy(targets, inputs)
    BCE_EXP = K.exp(-BCE)
    focal_loss = K.mean(alpha * K.pow((1-BCE_EXP), gamma) * BCE)
    
    return focal_loss

def total_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    return dice_loss(y_true, y_pred) + FocalLoss(y_true, y_pred, 0.25,2)
def precision(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision
def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())
def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

def iou_score(y_true, y_pred):
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true + y_pred, axis=[1, 2, 3]) - intersection
    iou = (intersection + 1e-5) / (union + 1e-5)
    return iou

# %%
model.load_weights("/kaggle/working/WNet_maxpool.h5")
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = 0.00001), loss={'output_1':total_loss},
              loss_weights = {'output_1':1},
              metrics = {"output_1":[iou_score,dice_coeff,tf.keras.metrics.Precision(),
    tf.keras.metrics.Recall(),sensitivity,specificity,tf.keras.metrics.AUC()]})

# %% [markdown]
# # Preparing Testing Data

# %%
import os
import pandas as pd
from tqdm import tqdm

def read_patch_paths(image_folder, mask_folder):
    image_paths = []
    mask_paths = []

    # Get a list of image patch files in the folder
    image_files = os.listdir(image_folder)

    # Assuming the file names are the same in the mask folder
    for file_name in tqdm(image_files):
        image_path = os.path.join(image_folder, file_name)
        mask_path = os.path.join(mask_folder, file_name)

        # Check if both image and mask paths exist
        if os.path.exists(image_path) and os.path.exists(mask_path):
            image_paths.append(image_path)
            mask_paths.append(mask_path)

    # Create a DataFrame
    df = pd.DataFrame({'Image': image_paths, 'Mask': mask_paths})
    return df

# Specify the paths to the image and mask patch folders
image_patch_folder = "/kaggle/input/testing-patches-he-512-idrid/HE_patches_test/image_patches_512_no_overlap"
mask_patch_folder = "/kaggle/input/testing-patches-he-512-idrid/HE_patches_test/mask_patches_512_no_overlap"

# Read patch paths and create a DataFrame
df_patches_test = read_patch_paths(image_patch_folder, mask_patch_folder)
# Out:
# 100%|██████████| 456/456 [00:00<00:00, 526.09it/s]

# %%
import cv2
import numpy as np
import albumentations as A
from tensorflow.keras.utils import Sequence
from sklearn.preprocessing import MinMaxScaler

scaler=MinMaxScaler()
def apply_clahe(image):
    lab = cv2.cvtColor(image, cv2.COLOR_BGR2LAB)
    l, a, b = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    cl = clahe.apply(l)
    limg = cv2.merge((cl, a, b))
    clahe_image = cv2.cvtColor(limg, cv2.COLOR_LAB2RGB)
    return clahe_image

class CustomDataGenerator(Sequence):
    def __init__(self, df, batch_size, image_size, shuffle=True):
        self.df = df
        self.batch_size = batch_size
        self.image_size = image_size
        self.shuffle = shuffle
        self.on_epoch_end()
        self.transform = A.Compose([
            A.HorizontalFlip(p=0.5),
            A.VerticalFlip(p=0.5),
            #A.RandomBrightnessContrast(p=0.2),
            #A.Rotate(limit=10, p=0.3)
        ])

    def __len__(self):
        return int(np.ceil(len(self.df) / float(self.batch_size)))

    def on_epoch_end(self):
        if self.shuffle:
            self.df = self.df.sample(frac=1).reset_index(drop=True)

    def __getitem__(self, index):
        batch_df = self.df[index * self.batch_size : (index + 1) * self.batch_size]

        images = []
        masks = []

        for i, row in batch_df.iterrows():

            image = cv2.imread(row['Image'], cv2.IMREAD_COLOR)
            image = apply_clahe(image)
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            image = cv2.resize(image, self.image_size)
            #shape = image.shape
            #image = scaler.fit_transform(image.reshape(-1, shape[-1])).reshape(shape)
            image = image/np.max(image)
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

            mask_path = row['Mask']
            if mask_path:
                mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
                mask = cv2.resize(mask, self.image_size)
                mask=mask>0
    

            augmented = self.transform(image=image, mask=mask)
            #images.append(augmented['image'])
            #masks.append(augmented['mask'])
            images.append(image)
            masks.append(mask)
        
                

        #images = np.expand_dims(np.array(images, dtype=np.float32), axis=-1)
        images = np.array(images, dtype=np.float32)
        masks = np.expand_dims(np.array(masks, dtype=np.float32), axis=-1)
        return  images, masks

# Example usage of the CustomDataGenerator
test_generator = CustomDataGenerator(df_patches_test, batch_size=16, image_size=(256, 256), shuffle=False)

# %%
results = model.evaluate(test_generator)
# Out:
# 29/29 [==============================] - 21s 513ms/step - loss: 0.2682 - iou_score: 0.4935 - dice_coeff: 0.7521 - precision_1: 0.7869 - recall_1: 0.7331 - sensitivity: 0.7569 - specificity: 0.9933 - auc_1: 0.9211

# %%
#!zip -r weights_WNet_Res50_AT_CL.zip /kaggle/working/WNet_maxpool.h5

# %%
#from IPython.display import FileLink
#FileLink(r'weights_WNet_Res50_AT_CL.zip')
